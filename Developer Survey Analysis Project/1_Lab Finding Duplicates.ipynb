# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding Duplicates Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Introduction

# %% [markdown]
# Data wrangling is a critical step in preparing datasets for analysis, and handling duplicates plays a key role in ensuring data accuracy. In this lab, you will focus on identifying and removing duplicate entries from your dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# 1. Identify duplicate rows in the dataset and analyze their characteristics.
# 2. Visualize the distribution of duplicates based on key attributes.
# 3. Remove duplicate values strategically based on specific criteria.
# 4. Outline the process of verifying and documenting duplicate removal.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Install the needed library

# %%
# !pip install pandas
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 204.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 208.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 148.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 143.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 94.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 172.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# Import pandas module

# %%
import pandas as pd

# %% [markdown]
# Import matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Load the dataset into a dataframe**

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %%
# Load the dataset directly from the URL
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/VYPrOu0Vs3I0hKLLjiPGrA/survey-data-with-duplicate.csv"
df = pd.read_csv(file_path)

# Display the first few rows
df.shape[0]
# Out:
# 65457

# %% [markdown]
# Load the data into a pandas dataframe:

# %% [markdown]
# Note: If you are working on a local Jupyter environment, you can use the URL directly in the pandas.read_csv() function as shown below:

# %%
#df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv")
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# ## Identify and Analyze Duplicates

# %% [markdown]
# ### Task 1: Identify Duplicate Rows
# 1. Count the number of duplicate rows in the dataset.
# 3. Display the first few duplicate rows to understand their structure.

# %%
## Write your code here
print(df.duplicated().value_counts())
df[df.duplicated()].head()
# Out:
# False    65437
# True        20
# Name: count, dtype: int64
#        ResponseId                      MainBranch                 Age  \
# 65437           1  I am a developer by profession  Under 18 years old
# 65438           2  I am a developer by profession     35-44 years old
# 65439           3  I am a developer by profession     45-54 years old
# 65440           4           I am learning to code     18-24 years old
# 65441           5  I am a developer by profession     18-24 years old
#
#                 Employment RemoteWork   Check  \
# 65437  Employed, full-time     Remote  Apples
# 65438  Employed, full-time     Remote  Apples
# 65439  Employed, full-time     Remote  Apples
# 65440   Student, full-time        NaN  Apples
# 65441   Student, full-time        NaN  Apples
#
#                                         CodingActivities  \
# 65437                                              Hobby
# 65438  Hobby;Contribute to open-source projects;Other...
# ...

# %% [markdown]
# ### Task 2: Analyze Characteristics of Duplicates
# 1. Identify duplicate rows based on selected columns such as MainBranch, Employment, and RemoteWork. Analyse which columns frequently contain identical values within these duplicate rows.
# 2. Analyse the characteristics of rows that are duplicates based on a subset of columns, such as MainBranch, Employment, and RemoteWork. Determine which columns frequently have identical values across these rows.
# ### Задача 2: Анализ характеристик дубликатов
# Определите дублирующиеся строки на основе выбранных столбцов, таких как MainBranch, Employment и RemoteWork. Проанализируйте, какие столбцы часто содержат идентичные значения в этих дублирующихся строках.
# Проанализируйте характеристики строк, которые являются дубликатами на основе подмножества столбцов, таких как MainBranch, Employment и RemoteWork. Определите, какие столбцы часто имеют идентичные значения в этих строках.

# %%
## Write your code here
dupl_cols = ['MainBranch', 'Employment', 'RemoteWork']
dupl = df[df.duplicated(subset = dupl_cols, keep = False)]
unique = dupl.groupby(dupl_cols).nunique()
unique
# Out:
#                                                                                                                                             ResponseId  \
# MainBranch                                         Employment                                         RemoteWork
# I am a developer by profession                     Employed, full-time                                Hybrid (some remote, some in-person)       15286
#                                                                                                       In-person                                   7118
#                                                                                                       Remote                                     12191
#                                                    Employed, full-time;Employed, part-time            Hybrid (some remote, some in-person)          78
# ...

# %% [markdown]
# ### Task 3: Visualize Duplicates Distribution
# 1. Create visualizations to show the distribution of duplicates across different categories.
# 2. Use bar charts or pie charts to represent the distribution of duplicates by Country and Employment.
# ### Задача 3: Визуализировать распределение дубликатов¶
# 1. Создайте визуализации, чтобы показать распределение дубликатов по различным категориям.
# 2.Используйте столбчатые диаграммы или круговые диаграммы для представления распределения дубликатов по странам и занятости.

# %%
## Write your code here
co_country = dupl['Country'].value_counts().head(10)
co_country = co_country.rename({'United Kingdom of Great Britain and Northern Ireland' : 'UK',
                               'United States of America': 'USA'})
emp = dupl['Employment'].value_counts().head(10)

fig = plt.figure(figsize =(14,6))
ax0=fig.add_subplot(1,2,2)
emp.plot(kind = 'pie', ax = ax0, startangle = 45)

ax1=fig.add_subplot(1,2,1)
co_country.plot(kind = 'bar', ax=ax1)
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45, ha='right')

ax0.set_title('Top 10 Countries with Duplicates')
ax1.set_title('Top 10 Employment Type with Duplicates')
# Out:
# Text(0.5, 1.0, 'Top 10 Employment Type with Duplicates')

# %%
duplic = df[df.duplicated(subset = ['ResponseId'])]
duplic
# Out:
#        ResponseId                                         MainBranch  \
# 65437           1                     I am a developer by profession
# 65438           2                     I am a developer by profession
# 65439           3                     I am a developer by profession
# 65440           4                              I am learning to code
# 65441           5                     I am a developer by profession
# 65442           6                        I code primarily as a hobby
# 65443           7  I am not primarily a developer, but I write co...
# 65444           8                              I am learning to code
# 65445           9                        I code primarily as a hobby
# 65446          10                     I am a developer by profession
# 65447       18522                     I am a developer by profession
# 65448       49767                        I code primarily as a hobby
# 65449       51198                     I am a developer by profession
# ...

# %% [markdown]
# ### Task 4: Strategic Removal of Duplicates
# 1. Decide which columns are critical for defining uniqueness in the dataset.
# 2. Remove duplicates based on a subset of columns if complete row duplication is not a good criterion.

# %%
print(df.nunique().sort_values(ascending=False).head(10))
# Out:
# ResponseId                      65437
# LanguageHaveWorkedWith          23864
# LanguageWantToWorkWith          22769
# ToolsTechHaveWorkedWith         19883
# ToolsTechWantToWorkWith         16549
# NEWCollabToolsHaveWorkedWith    14168
# LanguageAdmired                 12335
# WebframeHaveWorkedWith          12235
# ToolsTechAdmired                11804
# WebframeWantToWorkWith          11654
# dtype: int64

# %%
## Write your code here
crit = df[['Employment', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith']]
df_clean = df.drop_duplicates(subset = crit)
df_clean.tail(5)
# Out:
#        ResponseId                                         MainBranch  \
# 65414       65415                     I am a developer by profession
# 65427       65428  I am not primarily a developer, but I write co...
# 65431       65432                     I am a developer by profession
# 65435       65436                     I am a developer by profession
# 65436       65437                        I code primarily as a hobby
#
#                    Age                                         Employment  \
# 65414  18-24 years old                                Employed, full-time
# 65427  25-34 years old  Not employed, but looking for work;Employed, p...
# 65431  45-54 years old                                Employed, full-time
# 65435  18-24 years old                                Employed, full-time
# 65436  18-24 years old                                 Student, full-time
#
#                                  RemoteWork   Check  \
# ...

# %% [markdown]
# ## Verify and Document Duplicate Removal Process

# %% [markdown]
# ### Task 5: Documentation
# 1. Document the process of identifying and removing duplicates.

# %% [raw]
# # Write your explanation here
# We identified duplicates by analyzing the columns MainBranch, Employment, and RemoteWork to see which combinations of responses repeated among participants. We used df.duplicated() and groupby().nunique() to inspect these columns and determine which rows represented repeated or similar responses. Based on this analysis, these columns were selected to define meaningful uniqueness before removing duplicates with df.drop_duplicates().

# %% [markdown]
# 2. Explain the reasoning behind selecting specific columns for identifying and removing duplicates.

# %% [raw]
# # Write your explanation here
# We identified duplicates based on LanguageHaveWorkedWith, LanguageWantToWorkWith, and Employment, as these columns capture the core responses and meaningful uniqueness of participants. Employment was included because its specific sequence of positions is unlikely to repeat exactly. ResponseId was not used for identifying duplicates, as it is not a unique key but simply a sequential number assigned to each survey participant. Duplicates were removed using df.drop_duplicates() on this subset, keeping the first occurrence while retaining all other columns.

# %% [markdown]
# ### Summary and Next Steps
# **In this lab, you focused on identifying and analyzing duplicate rows within the dataset.**
#
# - You employed various techniques to explore the nature of duplicates and applied strategic methods for their removal.
# - For additional analysis, consider investigating the impact of duplicates on specific analyses and how their removal affects the results.
# - This version of the lab is more focused on duplicate analysis and handling, providing a structured approach to deal with duplicates in a dataset effectively.

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-11- 05|1.3|Madhusudhan Moole|Updated lab|
# |2024-10-28|1.2|Madhusudhan Moole|Updated lab|
# |2024-09-24|1.1|Madhusudhan Moole|Updated lab|
# |2024-09-23|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
